# %% [markdown]
# # DEC Assignment 2
# ### Name: Om Walkey   rollno:30

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Computer\\Downloads\\Emp.csv")

# %%
df
df.head()
# Out:
#    empno       ename         job        DOJ        DOB  deptid   salary
# 0      1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1      2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2      3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3      4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4      5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0

# %%
df.tail()
# Out:
#     empno   ename         job        DOJ        DOB  deptid   salary
# 7       8  Khushi     Manager  21-Mar-12   19970120    20.0  56000.0
# 8       9   Sayee      Cleark  16-Mar-12      36029     NaN  21000.0
# 9      10   Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11  Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1    Anil       Clerk        NaN        NaN     NaN      NaN

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12   19970120    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12      36029     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# ...

# %%
df.shape
# Out:
# (12, 7)

# %%
df.dtypes
# Out:
# empno       int64
# ename      object
# job        object
# DOJ        object
# DOB        object
# deptid    float64
# salary    float64
# dtype: object

# %%
df.size
# Out:
# 84

# %%
#check if missing values are in DF
df.info
# Out:
# <bound method DataFrame.info of     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12   19970120    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12      36029     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# ...

# %%
#to check if missing values are there method 2
df.isna()
# Out:
#     empno  ename    job    DOJ    DOB  deptid  salary
# 0   False  False  False   True   True    True    True
# 1   False  False   True  False  False   False   False
# 2   False  False  False  False  False   False   False
# 3   False  False  False  False  False   False    True
# 4   False  False  False  False  False   False   False
# 5   False  False  False  False  False   False   False
# 6   False  False  False  False  False   False   False
# 7   False  False  False  False  False   False   False
# 8   False  False  False  False  False    True   False
# 9   False  False  False  False  False   False   False
# 10  False  False  False  False  False   False   False
# 11  False  False  False   True   True    True    True

# %%
#to find sum of missing values in each columns
df.isna().sum()
# Out:
# empno     0
# ename     0
# job       1
# DOJ       2
# DOB       2
# deptid    3
# salary    3
# dtype: int64

# %%
df.isna().sum().plot(kind='bar')

# %%
df.isna().sum().plot(kind='pie')

# %%
#drop all the missing values
df.dropna()
# Out:
#     empno   ename         job        DOJ        DOB  deptid   salary
# 2       3  Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 4       5   Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6   Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7   Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8  Khushi     Manager  21-Mar-12   19970120    20.0  56000.0
# 9      10   Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11  Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0

# %%
#thresh if for minimum present values
df.dropna(axis=1,how='any',thresh=10,inplace=False)
# Out:
#     empno       ename         job        DOJ        DOB
# 0       1        Anil       Clerk        NaN        NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97
# 7       8      Khushi     Manager  21-Mar-12   19970120
# 8       9       Sayee      Cleark  16-Mar-12      36029
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91
# 11      1        Anil       Clerk        NaN        NaN

# %%
df.dropna(axis=0,how='any',thresh=5,inplace=False)
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12   19970120    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12      36029     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0

# %%
#use default values in place of missing values
df.fillna(0)
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk          0          0     0.0      0.0
# 1       2  Balkrushna           0  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      0.0
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12   19970120    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12      36029     0.0  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk          0          0     0.0      0.0

# %%
df[["job"]].fillna("clerk")
# Out:
#            job
# 0        Clerk
# 1        clerk
# 2      Manager
# 3      Manager
# 4   Accountant
# 5   Accountant
# 6      Manager
# 7      Manager
# 8       Cleark
# 9   Accountant
# 10  Accountant
# 11       Clerk

# %%
df.bfill()
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk  15-Jul-17  16-Mar-12    10.0  10000.0
# 1       2  Balkrushna     Manager  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0  45000.0
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12   19970120    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12      36029    30.0  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk        NaN        NaN     NaN      NaN

# %%
df.ffill()
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna       Clerk  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0  50000.0
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12   19970120    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12      36029    20.0  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk  24-Mar-14  24-Mar-91    30.0  47000.0

# %%
v1=df["deptid"].median()
v1
df["deptid"].fillna(v1)
# Out:
# 0     20.0
# 1     10.0
# 2     20.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     20.0
# 7     20.0
# 8     20.0
# 9     30.0
# 10    30.0
# 11    20.0
# Name: deptid, dtype: float64

# %%
import numpy as np
df["deptid"].replace(np.NaN,10)
# Out:
# 0     10.0
# 1     10.0
# 2     20.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     20.0
# 7     20.0
# 8     10.0
# 9     30.0
# 10    30.0
# 11    10.0
# Name: deptid, dtype: float64

# %%
from sklearn.impute import SimpleImputer
SimpleImputer(strategy="most_frequent").fit_transform(df[["salary"]])  #"mean" ,"median","most_frequent"
# Out:
# array([[45000.],
#        [10000.],
#        [50000.],
#        [45000.],
#        [45000.],
#        [45000.],
#        [52000.],
#        [56000.],
#        [21000.],
#        [46000.],
#        [47000.],
#        [45000.]])

# %%
df.duplicated(subset=None,keep=False).value_counts()
# Out:
# False    10
# True      2
# dtype: int64

# %%
df.drop_duplicates(keep="first")
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12   19970120    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12      36029     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0

# %%
df.drop_duplicates(subset=['ename','deptid'],keep='first')
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12   19970120    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12      36029     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0

# %%
#handle inconsistencies
df['DOJ']= pd.to_datetime(df['DOJ'])
df['DOJ']
# Out:
# 0           NaT
# 1    2017-07-15
# 2    2012-03-16
# 3    2012-03-16
# 4    2017-03-18
# 5    2013-11-19
# 6    2012-03-20
# 7    2012-03-21
# 8    2012-03-16
# 9    2012-03-23
# 10   2014-03-24
# 11          NaT
# Name: DOJ, dtype: datetime64[ns]

# %%
pd.qcut(df['salary'], q=4)
df['salary_smooth'] = pd.qcut(df['salary'], q=4,labels=False,precision=0)
df
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary  \
# 0       1        Anil       Clerk        NaT        NaN     NaN      NaN
# 1       2  Balkrushna         NaN 2017-07-15  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager 2012-03-16  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager 2012-03-16  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant 2017-03-18  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant 2013-11-19  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager 2012-03-20  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager 2012-03-21   19970120    20.0  56000.0
# 8       9       Sayee      Cleark 2012-03-16      36029     NaN  21000.0
# 9      10       Sakhi  Accountant 2012-03-23  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant 2014-03-24  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk        NaT        NaN     NaN      NaN
#
#     salary_smooth
# ...
