# %% [markdown]
# # DEC Lab Assingment 1
#
# Name: Om Walkey
# Roll no: 30

# %%
import pandas as pd
df=pd.read_excel("D:\\myDB\\Absenteeism_at_work.xls")
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# 5     3                  23                 7                6        1
# 6    10                  22                 7                6        1
# 7    20                  23                 7                6        1
# 8    14                  19                 7                2        1
# 9     1                  22                 7                2        1
# 10   20                   1                 7                2        1
# 11   20                   1                 7                3        1
# ...

# %%
df.mean()
# Out:
# ID                                     18.017568
# Reason for absence                     19.216216
# Month of absence                        6.324324
# Day of the week                         3.914865
# Seasons                                 2.544595
# Transportation expense                221.329730
# Distance from Residence to Work        29.631081
# Service time                           12.554054
# Age                                    36.450000
# Work load Average/day              271490.235135
# Hit target                             94.587838
# Disciplinary failure                    0.054054
# Education                               1.291892
# Son                                     1.018919
# Social drinker                          0.567568
# Social smoker                           0.072973
# Pet                                     0.745946
# Weight                                 79.035135
# Height                                172.114865
# ...

# %%
df.head(4)          # display first 4
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0                  239554  ...                     0          1    2
# 1                  239554  ...                     1          1    1
# ...

# %%
df.mode()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0   3                  23                 3                2        4
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     179                               26            18   28
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0                  222196  ...                     0          1    0
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0               1              0    0      89     170               31
#
#    Absenteeism time in hours
# 0                          8
#
# [1 rows x 21 columns]

# %%
df.tail(4)              # display last 4
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 736   37                  264604  ...                     0          3    1
# ...

# %%
df.iloc[10:20]             # display between 10 to 20
# Out:
#     ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 10  20                   1                 7                2        1
# 11  20                   1                 7                3        1
# 12  20                  11                 7                4        1
# 13   3                  11                 7                4        1
# 14   3                  23                 7                4        1
# 15  24                  14                 7                6        1
# 16   3                  23                 7                6        1
# 17   3                  21                 7                2        1
# 18   6                  11                 7                5        1
# 19  33                  23                 8                4        1
#
#     Transportation expense  Distance from Residence to Work  Service time  \
# 10                     260                               50            11
# ...

# %%
df.dtypes            # data types
# Out:
# ID                                 int64
# Reason for absence                 int64
# Month of absence                   int64
# Day of the week                    int64
# Seasons                            int64
# Transportation expense             int64
# Distance from Residence to Work    int64
# Service time                       int64
# Age                                int64
# Work load Average/day              int64
# Hit target                         int64
# Disciplinary failure               int64
# Education                          int64
# Son                                int64
# Social drinker                     int64
# Social smoker                      int64
# Pet                                int64
# Weight                             int64
# Height                             int64
# Body mass index                    int64
# Absenteeism time in hours          int64
# dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
df.size                     # size of data
# Out:
# 15540

# %%
df.ndim                     # dimension
# Out:
# 2

# %%
df.shape                    # shape of dataset
# Out:
# (740, 21)

# %%
df.describe()                # Statistical summary of data
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
df["Age"].mean()
# Out:
# 36.45

# %%
Petcount=df[df["Pet"]>0]                #How many employees have pets ?
Petcount["Pet"].count()
# Out:
# 280

# %%
df["Month of absence"].mode()           # Month when most employees remain absent
# Out:
# 0    3
# dtype: int64

# %%
df["Day of the week"].mode()             ## What is the day of the week when most employees are absent ?
# Out:
# 0    2
# dtype: int64

# %%
SDcount=df[df["Social drinker"]>0]          ## How many employees are social drinkers ?
SDcount["Social drinker"].count()
# Out:
# 420

# %%
df["Age"].max()       # Max age of employee
# Out:
# 58

# %%
df["Age"].min()       # Min age of employee
# Out:
# 27

# %%
df["Age"].mean()      # What is the average age of employees ?
# Out:
# 36.45

# %%
df["Seasons"].mode()   # In which season most of the employees remain absent
# Out:
# 0    4
# dtype: int64

# %%
df["Distance from Residence to Work"].mean()      #What is the average distance of residence ?
# Out:
# 29.63108108108108

# %%
df["Reason for absence"].mode()         #What is the most common reason of absence ?
# Out:
# 0    23
# dtype: int64

# %%
df["Service time"].mode()             #What is the service time of most of the employees?
# Out:
# 0    18
# dtype: int64

# %%
Dcount=df[df["Disciplinary failure"]>0]
Dcount["Disciplinary failure"].count()         # How many disciplinary failure employees ?
# Out:
# 40

# %%
df["Education"].mode()              # What is the education of most employees ?
# Out:
# 0    1
# dtype: int64
